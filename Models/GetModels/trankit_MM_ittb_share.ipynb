# %%
# !rm -r sample_data/
# Out:
# rm: cannot remove 'sample_data/': No such file or directory

# %%
# !wget -nc https://a3s.fi/Latin-parsers-public/trankit-MM_ittb.zip
# !unzip -n trankit-MM_ittb.zip
# Out:
# File ‘trankit-MM_ittb.zip’ already there; not retrieving.
#
# Archive:  trankit-MM_ittb.zip

# %%
# !ls -lhR
# Out:
# .:
# total 38M
# drwxr-xr-x 3 root root 4.0K Apr  5 18:58 trankit
# -rw-r--r-- 1 root root  38M Apr  5 07:30 trankit-MM_ittb.zip
#
# ./trankit:
# total 4.0K
# drwxr-xr-x 3 root root 4.0K Apr  5 18:58 MM_ittb
#
# ./trankit/MM_ittb:
# total 4.0K
# drwxr-xr-x 3 root root 4.0K Apr  5 18:58 save_dir
#
# ./trankit/MM_ittb/save_dir:
# total 4.0K
# drwxr-xr-x 3 root root 4.0K Apr  5 07:11 xlm-roberta-base
#
# ./trankit/MM_ittb/save_dir/xlm-roberta-base:
# total 4.0K
# drwxr-xr-x 2 root root 4.0K Apr  5 07:11 customized-mwt
#
# ./trankit/MM_ittb/save_dir/xlm-roberta-base/customized-mwt:
# total 42M
# -rw-r--r-- 1 root root 3.1M Apr  4 16:21 customized-mwt_lemmatizer.pt
# -rw-r--r-- 1 root root 530K Apr  4 16:21 customized-mwt_mwt_expander.pt
# -rw-r--r-- 1 root root  29M Apr  4 16:22 customized-mwt.tagger.mdl
# -rw-r--r-- 1 root root 9.1M Apr  4 16:22 customized-mwt.tokenizer.mdl
# -rw-r--r-- 1 root root 235K Apr  4 16:21 customized-mwt.vocabs.json

# %%
# %pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (25.0.1)

# %%
# %pip uninstall -y torchvision
# %pip uninstall -y torchaudio
# %pip uninstall -y fastai
# In Colab 2025-04-04: These would conflict with torch 2.01, which is going to
# be installed in the next step.

# Installing trankit in the next step:
#  fastai 2.7.19 requires torchvision>=0.11, which is not installed.
# https://pytorch.org/get-started/previous-versions/ says 0.15.2 goes with 2.0.1
# %pip install torchvision==0.15.2
# Out:
# WARNING: Skipping torchaudio as it is not installed.
# Requirement already satisfied: torchvision==0.15.2 in /usr/local/lib/python3.11/dist-packages (0.15.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.2) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.2) (2.32.3)
# Requirement already satisfied: torch==2.0.1 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.2) (2.0.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.2) (11.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision==0.15.2) (3.18.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision==0.15.2) (4.13.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision==0.15.2) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision==0.15.2) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision==0.15.2) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision==0.15.2) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision==0.15.2) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision==0.15.2) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision==0.15.2) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision==0.15.2) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision==0.15.2) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision==0.15.2) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision==0.15.2) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision==0.15.2) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision==0.15.2) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision==0.15.2) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision==0.15.2) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchvision==0.15.2) (75.2.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchvision==0.15.2) (0.45.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch==2.0.1->torchvision==0.15.2) (3.31.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch==2.0.1->torchvision==0.15.2) (18.1.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.0.1->torchvision==0.15.2) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.0.1->torchvision==0.15.2) (1.3.0)

# %%
# 2025-04-04: Running trankit I get complaint about numpy 2
# %pip install "numpy<2"
# %pip install trankit
# Out:
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: trankit in /usr/local/lib/python3.11/dist-packages (1.1.2)
# Requirement already satisfied: adapters>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from trankit) (1.1.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from trankit) (4.47.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from trankit) (1.26.4)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from trankit) (5.29.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from trankit) (2.32.3)
# Requirement already satisfied: torch<=2.0.1,>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from trankit) (2.0.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from trankit) (4.67.1)
# Requirement already satisfied: langid==1.1.6 in /usr/local/lib/python3.11/dist-packages (from trankit) (1.1.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from trankit) (3.18.0)
# Requirement already satisfied: tokenizers>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from trankit) (0.21.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from trankit) (2024.11.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from trankit) (24.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from trankit) (0.2.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.11/dist-packages (from trankit) (0.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from trankit) (1.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers>=0.7.0->trankit) (0.30.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (4.13.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<=2.0.1,>=1.6.0->trankit) (75.2.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<=2.0.1,>=1.6.0->trankit) (0.45.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch<=2.0.1,>=1.6.0->trankit) (3.31.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch<=2.0.1,>=1.6.0->trankit) (18.1.8)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers->trankit) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers->trankit) (0.5.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->trankit) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->trankit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->trankit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->trankit) (2025.1.31)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from sacremoses->trankit) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from sacremoses->trankit) (1.4.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.7.0->trankit) (2025.3.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<=2.0.1,>=1.6.0->trankit) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch<=2.0.1,>=1.6.0->trankit) (1.3.0)

# %% [markdown]
# ---
#
# **Restart kernel here(?)**
#
# ---

# %%
import trankit
from trankit import Pipeline, trankit2conllu
# If you get an error about numpy not found, restart the kernel.

# %%
# !pwd
# %cd trankit/MM_ittb/
# !pwd
# Out:
# /content
# /content/trankit/MM_ittb
# /content/trankit/MM_ittb

# %%
trankit.verify_customized_pipeline(
    category='customized-mwt', # pipeline category
    save_dir='./save_dir', # directory used for saving models in previous steps
    embedding_name='xlm-roberta-base' # embedding version that we use for training our customized pipeline, by default, it is `xlm-roberta-base`
)
# Out:
# Customized pipeline is ready to use!
# It can be initialized as follows:
# -----------------------------------
# from trankit import Pipeline
# p = Pipeline(lang='customized-mwt', cache_dir='./save_dir')

# %%
p = Pipeline(lang='customized-mwt', cache_dir='./save_dir')
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# Loading pretrained XLM-Roberta, this may take a while...
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/adapters/composition.py:225: FutureWarning: Passing list objects for adapter activation is deprecated. Please use Stack or Fuse explicitly.
#   warnings.warn(
# Loading tokenizer for customized-mwt
# Loading tagger for customized-mwt
# Loading multi-word expander for customized-mwt
# Loading lemmatizer for customized-mwt
# ==================================================
# Active language: customized-mwt
# ==================================================

# %%
doc = '''In Catilinam orationes Cicero consul contra Catilinam et coniurationem eius declamavit.

Prima oratio, in senatu, brevis est, sed discipuli latinae linguae saepe eam legunt quod facilior lectu est quam alia carmina et orationes. '''

# perform all tasks on the input
processed_doc = p(doc)

# %%
from pprint import pprint

pprint(processed_doc)
# Out:
# {'lang': 'customized-mwt',
#  'sentences': [{'dspan': (0, 87),
#                 'id': 1,
#                 'text': 'In Catilinam orationes Cicero consul contra Catilinam '
#                         'et coniurationem eius declamavit.',
#                 'tokens': [{'deprel': 'case',
#                             'dspan': (0, 2),
#                             'feats': 'AdpType=Prep',
#                             'head': 2,
#                             'id': 1,
#                             'lemma': 'In',
#                             'span': (0, 2),
#                             'text': 'In',
#                             'upos': 'ADP',
#                             'xpos': 'S4'},
#                            {'deprel': 'obl',
#                             'dspan': (3, 12),
#                             'feats': 'Case=Acc|Gender=Fem|InflClass=IndEurA|Number=Sing',
#                             'head': 11,
#                             'id': 2,
#                             'lemma': 'Catilinam',
#                             'span': (3, 12),
#                             'text': 'Catilinam',
#                             'upos': 'PROPN',
#                             'xpos': 'A1|grn1|casD|gen2'},
#                            {'deprel': 'obj',
#                             'dspan': (13, 22),
#                             'feats': 'Case=Acc|Gender=Fem|InflClass=IndEurX|Number=Plur',
#                             'head': 11,
#                             'id': 3,
#                             'lemma': 'oratio',
#                             'span': (13, 22),
#                             'text': 'orationes',
#                             'upos': 'NOUN',
#                             'xpos': 'C1|grn1|casM|gen2'},
#                            {'deprel': 'nsubj',
#                             'dspan': (23, 29),
#                             'feats': 'Case=Nom|Gender=Masc|InflClass=IndEurX|Number=Sing',
#                             'head': 11,
#                             'id': 4,
#                             'lemma': 'Cicero',
#                             'span': (23, 29),
#                             'text': 'Cicero',
#                             'upos': 'PROPN',
#                             'xpos': 'C1|grn1|casA|gen1'},
#                            {'deprel': 'nmod',
#                             'dspan': (30, 36),
#                             'feats': 'Case=Nom|Gender=Masc|InflClass=IndEurX|Number=Sing',
#                             'head': 4,
#                             'id': 5,
#                             'lemma': 'consul',
#                             'span': (30, 36),
#                             'text': 'consul',
#                             'upos': 'NOUN',
#                             'xpos': 'C1|grn1|casA|gen1'},
#                            {'deprel': 'case',
#                             'dspan': (37, 43),
#                             'feats': 'AdpType=Prep',
#                             'head': 7,
#                             'id': 6,
#                             'lemma': 'contra',
#                             'span': (37, 43),
#                             'text': 'contra',
#                             'upos': 'ADP',
#                             'xpos': 'S4'},
#                            {'deprel': 'obl',
#                             'dspan': (44, 53),
#                             'feats': 'Case=Acc|Gender=Fem|InflClass=IndEurA|Number=Sing',
#                             'head': 11,
#                             'id': 7,
#                             'lemma': 'Catilinam',
#                             'span': (44, 53),
#                             'text': 'Catilinam',
#                             'upos': 'PROPN',
#                             'xpos': 'A1|grn1|casD|gen2'},
#                            {'deprel': 'cc',
#                             'dspan': (54, 56),
#                             'head': 9,
#                             'id': 8,
#                             'lemma': 'et',
#                             'span': (54, 56),
#                             'text': 'et',
#                             'upos': 'CCONJ',
#                             'xpos': 'O4'},
#                            {'deprel': 'conj',
#                             'dspan': (57, 70),
#                             'feats': 'Case=Acc|Gender=Fem|InflClass=IndEurX|Number=Sing',
#                             'head': 7,
#                             'id': 9,
#                             'lemma': 'coniurationem',
#                             'span': (57, 70),
#                             'text': 'coniurationem',
#                             'upos': 'NOUN',
#                             'xpos': 'C1|grn1|casD|gen2|vgr1'},
#                            {'deprel': 'nmod',
#                             'dspan': (71, 75),
#                             'feats': 'Case=Gen|Gender=Masc|InflClass=LatPron|Number=Sing|Person=3|PronType=Prs',
#                             'head': 9,
#                             'id': 10,
#                             'lemma': 'is',
#                             'span': (71, 75),
#                             'text': 'eius',
#                             'upos': 'PRON',
#                             'xpos': 'F1|grn1|casB|gen1|vgr2'},
#                            {'deprel': 'root',
#                             'dspan': (76, 86),
#                             'feats': 'Aspect=Perf|InflClass=LatA|Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin|Voice=Act',
#                             'head': 0,
#                             'id': 11,
#                             'lemma': 'declamavit',
#                             'span': (76, 86),
#                             'text': 'declamavit',
#                             'upos': 'VERB',
#                             'xpos': 'J3|modA|tem4|gen6'},
#                            {'deprel': 'punct',
#                             'dspan': (86, 87),
#                             'head': 11,
#                             'id': 12,
#                             'lemma': '.',
#                             'span': (86, 87),
#                             'text': '.',
#                             'upos': 'PUNCT',
#                             'xpos': 'Punc'}]},
#                {'dspan': (89, 228),
#                 'id': 2,
#                 'text': 'Prima oratio, in senatu, brevis est, sed discipuli '
#                         'latinae linguae saepe eam legunt quod facilior lectu '
#                         'est quam alia carmina et orationes.',
#                 'tokens': [{'deprel': 'amod',
#                             'dspan': (89, 94),
#                             'feats': 'Case=Nom|Gender=Fem|InflClass=IndEurA|Number=Sing|NumType=Ord',
#                             'head': 2,
#                             'id': 1,
#                             'lemma': 'Prima',
#                             'span': (0, 5),
#                             'text': 'Prima',
#                             'upos': 'ADJ',
#                             'xpos': 'A1|grn1|casA|gen2'},
#                            {'deprel': 'nsubj',
#                             'dspan': (95, 101),
#                             'feats': 'Case=Nom|Gender=Fem|InflClass=IndEurX|Number=Sing',
#                             'head': 7,
#                             'id': 2,
#                             'lemma': 'oratio',
#                             'span': (6, 12),
#                             'text': 'oratio',
#                             'upos': 'NOUN',
#                             'xpos': 'C1|grn1|casA|gen2'},
#                            {'deprel': 'punct',
#                             'dspan': (101, 102),
#                             'head': 2,
#                             'id': 3,
#                             'lemma': ',',
#                             'span': (12, 13),
#                             'text': ',',
#                             'upos': 'PUNCT',
#                             'xpos': 'Punc'},
#                            {'deprel': 'case',
#                             'dspan': (103, 105),
#                             'feats': 'AdpType=Prep',
#                             'head': 5,
#                             'id': 4,
#                             'lemma': 'in',
#                             'span': (14, 16),
#                             'text': 'in',
#                             'upos': 'ADP',
#                             'xpos': 'S4'},
#                            {'deprel': 'obl',
#                             'dspan': (106, 112),
#                             'feats': 'Case=Abl|Gender=Masc|InflClass=IndEurU|Number=Sing',
#                             'head': 7,
#                             'id': 5,
#                             'lemma': 'senatu',
#                             'span': (17, 23),
#                             'text': 'senatu',
#                             'upos': 'NOUN',
#                             'xpos': 'D1|grn1|casF|gen1'},
#                            {'deprel': 'punct',
#                             'dspan': (112, 113),
#                             'head': 5,
#                             'id': 6,
#                             'lemma': ',',
#                             'span': (23, 24),
#                             'text': ',',
#                             'upos': 'PUNCT',
#                             'xpos': 'Punc'},
#                            {'deprel': 'root',
#                             'dspan': (114, 120),
#                             'feats': 'Case=Nom|Gender=Fem|InflClass=IndEurI|Number=Sing',
#                             'head': 0,
#                             'id': 7,
#                             'lemma': 'brevis',
#                             'span': (25, 31),
#                             'text': 'brevis',
#                             'upos': 'ADJ',
#                             'xpos': 'C1|grn1|casA|gen2'},
#                            {'deprel': 'cop',
#                             'dspan': (121, 124),
#                             'feats': 'Aspect=Imp|InflClass=LatAnom|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#                             'head': 7,
#                             'id': 8,
#                             'lemma': 'sum',
#                             'span': (32, 35),
#                             'text': 'est',
#                             'upos': 'AUX',
#                             'xpos': 'N3|modA|tem1|gen6'},
#                            {'deprel': 'punct',
#                             'dspan': (124, 125),
#                             'head': 16,
#                             'id': 9,
#                             'lemma': ',',
#                             'span': (35, 36),
#                             'text': ',',
#                             'upos': 'PUNCT',
#                             'xpos': 'Punc'},
#                            {'deprel': 'cc',
#                             'dspan': (126, 129),
#                             'head': 16,
#                             'id': 10,
#                             'lemma': 'sed',
#                             'span': (37, 40),
#                             'text': 'sed',
#                             'upos': 'CCONJ',
#                             'xpos': 'O4|vgr1'},
#                            {'deprel': 'nsubj',
#                             'dspan': (130, 139),
#                             'feats': 'Case=Nom|Gender=Masc|InflClass=IndEurO|Number=Plur',
#                             'head': 16,
#                             'id': 11,
#                             'lemma': 'discipulus',
#                             'span': (41, 50),
#                             'text': 'discipuli',
#                             'upos': 'NOUN',
#                             'xpos': 'B1|grn1|casJ|gen1'},
#                            {'deprel': 'amod',
#                             'dspan': (140, 147),
#                             'feats': 'Case=Gen|Gender=Fem|InflClass=IndEurA|Number=Sing',
#                             'head': 13,
#                             'id': 12,
#                             'lemma': 'latinae',
#                             'span': (51, 58),
#                             'text': 'latinae',
#                             'upos': 'ADJ',
#                             'xpos': 'A1|grn1|casB|gen2'},
#                            {'deprel': 'nmod',
#                             'dspan': (148, 155),
#                             'feats': 'Case=Gen|Gender=Fem|InflClass=IndEurA|Number=Sing',
#                             'head': 11,
#                             'id': 13,
#                             'lemma': 'lingua',
#                             'span': (59, 66),
#                             'text': 'linguae',
#                             'upos': 'NOUN',
#                             'xpos': 'A1|grn1|casB|gen2|vgr1'},
#                            {'deprel': 'advmod:tmod',
#                             'dspan': (156, 161),
#                             'feats': 'AdvType=Tim',
#                             'head': 16,
#                             'id': 14,
#                             'lemma': 'saepe',
#                             'span': (67, 72),
#                             'text': 'saepe',
#                             'upos': 'ADV',
#                             'xpos': 'O4|vgr1'},
#                            {'deprel': 'obj',
#                             'dspan': (162, 165),
#                             'feats': 'Case=Acc|Gender=Fem|InflClass=LatPron|Number=Sing|Person=3|PronType=Prs',
#                             'head': 16,
#                             'id': 15,
#                             'lemma': 'is',
#                             'span': (73, 76),
#                             'text': 'eam',
#                             'upos': 'PRON',
#                             'xpos': 'F1|grn1|casD|gen2'},
#                            {'deprel': 'conj',
#                             'dspan': (166, 172),
#                             'feats': 'Aspect=Imp|InflClass=LatX|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act',
#                             'head': 7,
#                             'id': 16,
#                             'lemma': 'legunt',
#                             'span': (77, 83),
#                             'text': 'legunt',
#                             'upos': 'VERB',
#                             'xpos': 'L3|modA|tem1|gen9'},
#                            {'deprel': 'nsubj',
#                             'dspan': (173, 177),
#                             'feats': 'Case=Nom|Gender=Neut|InflClass=LatPron|Number=Sing|PronType=Rel',
#                             'head': 18,
#                             'id': 17,
#                             'lemma': 'qui',
#                             'span': (84, 88),
#                             'text': 'quod',
#                             'upos': 'PRON',
#                             'xpos': 'F1|grn1|casA|gen3'},
#                            {'deprel': 'acl:relcl',
#                             'dspan': (178, 186),
#                             'feats': 'Case=Nom|Degree=Cmp|Gender=Neut|InflClass=IndEurX|Number=Sing',
#                             'head': 16,
#                             'id': 18,
#                             'lemma': 'facilis',
#                             'span': (89, 97),
#                             'text': 'facilior',
#                             'upos': 'ADJ',
#                             'xpos': 'C1|grn2|casA|gen3'},
#                            {'deprel': 'obl',
#                             'dspan': (187, 192),
#                             'feats': 'Case=Abl|Gender=Masc|InflClass=IndEurU|Number=Sing',
#                             'head': 18,
#                             'id': 19,
#                             'lemma': 'lectu',
#                             'span': (98, 103),
#                             'text': 'lectu',
#                             'upos': 'NOUN',
#                             'xpos': 'D1|grn1|casF|gen1'},
#                            {'deprel': 'cop',
#                             'dspan': (193, 196),
#                             'feats': 'Aspect=Imp|InflClass=LatAnom|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#                             'head': 18,
#                             'id': 20,
#                             'lemma': 'sum',
#                             'span': (104, 107),
#                             'text': 'est',
#                             'upos': 'AUX',
#                             'xpos': 'N3|modA|tem1|gen6'},
#                            {'deprel': 'mark',
#                             'dspan': (197, 201),
#                             'feats': 'PronType=Rel',
#                             'head': 23,
#                             'id': 21,
#                             'lemma': 'quam',
#                             'span': (108, 112),
#                             'text': 'quam',
#                             'upos': 'SCONJ',
#                             'xpos': 'O4'},
#                            {'deprel': 'det',
#                             'dspan': (202, 206),
#                             'feats': 'Case=Nom|Gender=Fem|InflClass=LatPron|Number=Sing|PronType=Con',
#                             'head': 23,
#                             'id': 22,
#                             'lemma': 'alius',
#                             'span': (113, 117),
#                             'text': 'alia',
#                             'upos': 'DET',
#                             'xpos': 'F1|grn1|casA|gen2'},
#                            {'deprel': 'advcl:cmp',
#                             'dspan': (207, 214),
#                             'feats': 'Case=Nom|Gender=Fem|InflClass=IndEurA|Number=Sing',
#                             'head': 18,
#                             'id': 23,
#                             'lemma': 'carmen',
#                             'span': (118, 125),
#                             'text': 'carmina',
#                             'upos': 'NOUN',
#                             'xpos': 'A1|grn1|casA|gen2|vgr1'},
#                            {'deprel': 'cc',
#                             'dspan': (215, 217),
#                             'head': 25,
#                             'id': 24,
#                             'lemma': 'et',
#                             'span': (126, 128),
#                             'text': 'et',
#                             'upos': 'CCONJ',
#                             'xpos': 'O4'},
#                            {'deprel': 'conj',
#                             'dspan': (218, 227),
#                             'feats': 'Case=Nom|Gender=Fem|InflClass=IndEurX|Number=Plur',
#                             'head': 23,
#                             'id': 25,
#                             'lemma': 'oratio',
#                             'span': (129, 138),
#                             'text': 'orationes',
#                             'upos': 'NOUN',
#                             'xpos': 'C1|grn1|casJ|gen2'},
#                            {'deprel': 'punct',
#                             'dspan': (227, 228),
#                             'head': 7,
#                             'id': 26,
#                             'lemma': '.',
#                             'span': (138, 139),
#                             'text': '.',
#                             'upos': 'PUNCT',
#                             'xpos': 'Punc'}]}],
#  'text': 'In Catilinam orationes Cicero consul contra Catilinam et '
#          'coniurationem eius declamavit.\n'
#          '\n'
#          'Prima oratio, in senatu, brevis est, sed discipuli latinae linguae '
#          'saepe eam legunt quod facilior lectu est quam alia carmina et '
#          'orationes. '}

# %%
conlludoc = trankit2conllu(processed_doc)
print(conlludoc)
# Out:
# 1	In	In	ADP	S4	AdpType=Prep	2	case	_	_
# 2	Catilinam	Catilinam	PROPN	A1|grn1|casD|gen2	Case=Acc|Gender=Fem|InflClass=IndEurA|Number=Sing	11	obl	_	_
# 3	orationes	oratio	NOUN	C1|grn1|casM|gen2	Case=Acc|Gender=Fem|InflClass=IndEurX|Number=Plur	11	obj	_	_
# 4	Cicero	Cicero	PROPN	C1|grn1|casA|gen1	Case=Nom|Gender=Masc|InflClass=IndEurX|Number=Sing	11	nsubj	_	_
# 5	consul	consul	NOUN	C1|grn1|casA|gen1	Case=Nom|Gender=Masc|InflClass=IndEurX|Number=Sing	4	nmod	_	_
# 6	contra	contra	ADP	S4	AdpType=Prep	7	case	_	_
# 7	Catilinam	Catilinam	PROPN	A1|grn1|casD|gen2	Case=Acc|Gender=Fem|InflClass=IndEurA|Number=Sing	11	obl	_	_
# 8	et	et	CCONJ	O4	_	9	cc	_	_
# 9	coniurationem	coniurationem	NOUN	C1|grn1|casD|gen2|vgr1	Case=Acc|Gender=Fem|InflClass=IndEurX|Number=Sing	7	conj	_	_
# 10	eius	is	PRON	F1|grn1|casB|gen1|vgr2	Case=Gen|Gender=Masc|InflClass=LatPron|Number=Sing|Person=3|PronType=Prs	9	nmod	_	_
# 11	declamavit	declamavit	VERB	J3|modA|tem4|gen6	Aspect=Perf|InflClass=LatA|Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin|Voice=Act	0	root	_	_
# 12	.	.	PUNCT	Punc	_	11	punct	_	_
#
# 1	Prima	Prima	ADJ	A1|grn1|casA|gen2	Case=Nom|Gender=Fem|InflClass=IndEurA|Number=Sing|NumType=Ord	2	amod	_	_
# 2	oratio	oratio	NOUN	C1|grn1|casA|gen2	Case=Nom|Gender=Fem|InflClass=IndEurX|Number=Sing	7	nsubj	_	_
# 3	,	,	PUNCT	Punc	_	2	punct	_	_
# 4	in	in	ADP	S4	AdpType=Prep	5	case	_	_
# 5	senatu	senatu	NOUN	D1|grn1|casF|gen1	Case=Abl|Gender=Masc|InflClass=IndEurU|Number=Sing	7	obl	_	_
# 6	,	,	PUNCT	Punc	_	5	punct	_	_
# 7	brevis	brevis	ADJ	C1|grn1|casA|gen2	Case=Nom|Gender=Fem|InflClass=IndEurI|Number=Sing	0	root	_	_
# 8	est	sum	AUX	N3|modA|tem1|gen6	Aspect=Imp|InflClass=LatAnom|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	7	cop	_	_
# 9	,	,	PUNCT	Punc	_	16	punct	_	_
# 10	sed	sed	CCONJ	O4|vgr1	_	16	cc	_	_
# 11	discipuli	discipulus	NOUN	B1|grn1|casJ|gen1	Case=Nom|Gender=Masc|InflClass=IndEurO|Number=Plur	16	nsubj	_	_
# 12	latinae	latinae	ADJ	A1|grn1|casB|gen2	Case=Gen|Gender=Fem|InflClass=IndEurA|Number=Sing	13	amod	_	_
# 13	linguae	lingua	NOUN	A1|grn1|casB|gen2|vgr1	Case=Gen|Gender=Fem|InflClass=IndEurA|Number=Sing	11	nmod	_	_
# 14	saepe	saepe	ADV	O4|vgr1	AdvType=Tim	16	advmod:tmod	_	_
# 15	eam	is	PRON	F1|grn1|casD|gen2	Case=Acc|Gender=Fem|InflClass=LatPron|Number=Sing|Person=3|PronType=Prs	16	obj	_	_
# 16	legunt	legunt	VERB	L3|modA|tem1|gen9	Aspect=Imp|InflClass=LatX|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act	7	conj	_	_
# 17	quod	qui	PRON	F1|grn1|casA|gen3	Case=Nom|Gender=Neut|InflClass=LatPron|Number=Sing|PronType=Rel	18	nsubj	_	_
# 18	facilior	facilis	ADJ	C1|grn2|casA|gen3	Case=Nom|Degree=Cmp|Gender=Neut|InflClass=IndEurX|Number=Sing	16	acl:relcl	_	_
# 19	lectu	lectu	NOUN	D1|grn1|casF|gen1	Case=Abl|Gender=Masc|InflClass=IndEurU|Number=Sing	18	obl	_	_
# 20	est	sum	AUX	N3|modA|tem1|gen6	Aspect=Imp|InflClass=LatAnom|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	18	cop	_	_
# 21	quam	quam	SCONJ	O4	PronType=Rel	23	mark	_	_
# 22	alia	alius	DET	F1|grn1|casA|gen2	Case=Nom|Gender=Fem|InflClass=LatPron|Number=Sing|PronType=Con	23	det	_	_
# 23	carmina	carmen	NOUN	A1|grn1|casA|gen2|vgr1	Case=Nom|Gender=Fem|InflClass=IndEurA|Number=Sing	18	advcl:cmp	_	_
# 24	et	et	CCONJ	O4	_	25	cc	_	_
# 25	orationes	oratio	NOUN	C1|grn1|casJ|gen2	Case=Nom|Gender=Fem|InflClass=IndEurX|Number=Plur	23	conj	_	_
# 26	.	.	PUNCT	Punc	_	7	punct	_	_
