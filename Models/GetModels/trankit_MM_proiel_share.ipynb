# %%
# !rm -r sample_data/

# %%
# !wget -nc https://a3s.fi/Latin-parsers-public/trankit-MM_proiel.zip
# !unzip -n trankit-MM_proiel.zip
# Out:
# File ‘trankit-MM_ittb.zip’ already there; not retrieving.
#
# Archive:  trankit-MM_ittb.zip

# %%
# !ls -lhR
# Out:
# .:
# total 30M
# drwxr-xr-x 3 root root 4.0K Apr  5 19:48 trankit
# -rw-r--r-- 1 root root  30M Apr  5 20:00 trankit-MM_llct.zip
#
# ./trankit:
# total 4.0K
# drwxr-xr-x 3 root root 4.0K Apr  5 19:48 MM_llct
#
# ./trankit/MM_llct:
# total 4.0K
# drwxr-xr-x 3 root root 4.0K Apr  5 19:48 save_dir
#
# ./trankit/MM_llct/save_dir:
# total 4.0K
# drwxr-xr-x 5 root root 4.0K Apr  5 19:58 xlm-roberta-base
#
# ./trankit/MM_llct/save_dir/xlm-roberta-base:
# total 8.0K
# drwxr-xr-x 2 root root 4.0K Apr  5 19:56 customized-mwt
# drwxr-xr-x 6 root root 4.0K Apr  5 19:58 models--xlm-roberta-base
#
# ./trankit/MM_llct/save_dir/xlm-roberta-base/customized-mwt:
# total 33M
# -rw-r--r-- 1 root root    0 Apr  5 19:56 customized-mwt.downloaded
# -rw-r--r-- 1 root root 2.4M Apr  5 19:51 customized-mwt_lemmatizer.pt
# -rw-r--r-- 1 root root 530K Apr  5 19:51 customized-mwt_mwt_expander.pt
# -rw-r--r-- 1 root root  21M Apr  5 19:51 customized-mwt.tagger.mdl
# -rw-r--r-- 1 root root 9.1M Apr  5 19:51 customized-mwt.tokenizer.mdl
# -rw-r--r-- 1 root root  54K Apr  5 19:51 customized-mwt.vocabs.json
#
# ./trankit/MM_llct/save_dir/xlm-roberta-base/models--xlm-roberta-base:
# total 12K
# drwxr-xr-x 2 root root 4.0K Apr  5 19:58 blobs
# drwxr-xr-x 2 root root 4.0K Apr  5 19:58 refs
# drwxr-xr-x 3 root root 4.0K Apr  5 19:58 snapshots
#
# ./trankit/MM_llct/save_dir/xlm-roberta-base/models--xlm-roberta-base/blobs:
# total 1.1G
# -rw-r--r-- 1 root root  615 Apr  5 19:58 1960141250d189366dfb76630ba794a9c104ec07
# -rw-r--r-- 1 root root   25 Apr  5 19:58 34ddbd64a4cd3f2d9d8a9120d3662d0bf91baead
# -rw-r--r-- 1 root root 8.7M Apr  5 19:58 463f3414782c1c9405828c9b31bfa36dda1f45c5
# -rw-r--r-- 1 root root 1.1G Apr  5 19:58 6fd4797bc397c3b8b55d6bb5740366b57e6a3ce91c04c77f22aafc0c128e6feb
# -rw-r--r-- 1 root root 4.9M Apr  5 19:58 db9af13bf09fd3028ca32be90d3fb66d5e470399
#
# ./trankit/MM_llct/save_dir/xlm-roberta-base/models--xlm-roberta-base/refs:
# total 4.0K
# -rw-r--r-- 1 root root 40 Apr  5 19:58 main
#
# ./trankit/MM_llct/save_dir/xlm-roberta-base/models--xlm-roberta-base/snapshots:
# total 4.0K
# drwxr-xr-x 2 root root 4.0K Apr  5 19:58 e73636d4f797dec63c3081bb6ed5c7b0bb3f2089
#
# ./trankit/MM_llct/save_dir/xlm-roberta-base/models--xlm-roberta-base/snapshots/e73636d4f797dec63c3081bb6ed5c7b0bb3f2089:
# total 4.0K
# lrwxrwxrwx 1 root root 52 Apr  5 19:58 config.json -> ../../blobs/1960141250d189366dfb76630ba794a9c104ec07
# lrwxrwxrwx 1 root root 76 Apr  5 19:58 model.safetensors -> ../../blobs/6fd4797bc397c3b8b55d6bb5740366b57e6a3ce91c04c77f22aafc0c128e6feb
# lrwxrwxrwx 1 root root 52 Apr  5 19:58 sentencepiece.bpe.model -> ../../blobs/db9af13bf09fd3028ca32be90d3fb66d5e470399
# lrwxrwxrwx 1 root root 52 Apr  5 19:58 tokenizer_config.json -> ../../blobs/34ddbd64a4cd3f2d9d8a9120d3662d0bf91baead
# lrwxrwxrwx 1 root root 52 Apr  5 19:58 tokenizer.json -> ../../blobs/463f3414782c1c9405828c9b31bfa36dda1f45c5

# %%
# !mkdir -p trankit/MM_proiel/save_dir/xlm-roberta-base/customized-mwt

# %%
# %pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.0.1-py3-none-any.whl.metadata (3.7 kB)
# Downloading pip-25.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 17.1 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-25.0.1

# %%
# %pip uninstall -y torchvision
# %pip uninstall -y torchaudio
# %pip uninstall -y fastai
# In Colab 2025-04-04: These would conflict with torch 2.01, which is going to
# be installed in the next step.

# Installing trankit in the next step:
#  fastai 2.7.19 requires torchvision>=0.11, which is not installed.
# https://pytorch.org/get-started/previous-versions/ says 0.15.2 goes with 2.0.1
# %pip install torchvision==0.15.2
# Out:
# Found existing installation: torchaudio 2.6.0+cu124
# Uninstalling torchaudio-2.6.0+cu124:
#   Successfully uninstalled torchaudio-2.6.0+cu124
# Collecting torchvision==0.15.2
#   Downloading torchvision-0.15.2-cp311-cp311-manylinux1_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.2) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.2) (2.32.3)
# Collecting torch==2.0.1 (from torchvision==0.15.2)
#   Downloading torch-2.0.1-cp311-cp311-manylinux1_x86_64.whl.metadata (24 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.2) (11.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision==0.15.2) (3.18.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision==0.15.2) (4.13.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision==0.15.2) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision==0.15.2) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1->torchvision==0.15.2) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch==2.0.1->torchvision==0.15.2)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch==2.0.1->torchvision==0.15.2)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch==2.0.1->torchvision==0.15.2)
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch==2.0.1->torchvision==0.15.2)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch==2.0.1->torchvision==0.15.2)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch==2.0.1->torchvision==0.15.2)
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch==2.0.1->torchvision==0.15.2)
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch==2.0.1->torchvision==0.15.2)
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch==2.0.1->torchvision==0.15.2)
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu11==2.14.3 (from torch==2.0.1->torchvision==0.15.2)
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch==2.0.1->torchvision==0.15.2)
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.0.0 (from torch==2.0.1->torchvision==0.15.2)
#   Downloading triton-2.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.0 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchvision==0.15.2) (75.2.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchvision==0.15.2) (0.45.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch==2.0.1->torchvision==0.15.2) (3.31.6)
# Collecting lit (from triton==2.0.0->torch==2.0.1->torchvision==0.15.2)
#   Downloading lit-18.1.8-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.0.1->torchvision==0.15.2) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.0.1->torchvision==0.15.2) (1.3.0)
# Downloading torchvision-0.15.2-cp311-cp311-manylinux1_x86_64.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 67.0 MB/s eta 0:00:00
# Downloading torch-2.0.1-cp311-cp311-manylinux1_x86_64.whl (619.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 46.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 64.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 128.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 121.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 37.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 39.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl (168.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 60.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 51.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 55.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 63.1 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 62.5 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
# Downloading triton-2.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 56.9 MB/s eta 0:00:00
# Downloading lit-18.1.8-py3-none-any.whl (96 kB)
# Installing collected packages: lit, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, nvidia-cusolver-cu11, nvidia-cudnn-cu11, triton, torch, torchvision
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.21.0+cu124
#     Uninstalling torchvision-0.21.0+cu124:
#       Successfully uninstalled torchvision-0.21.0+cu124
# Successfully installed lit-18.1.8 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 torch-2.0.1 torchvision-0.15.2 triton-2.0.0

# %%
# 2025-04-04: Running trankit I get complaint about numpy 2
# %pip install "numpy<2"
# %pip install trankit
# Out:
# Collecting numpy<2
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 94.6 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# Successfully installed numpy-1.26.4
# Collecting trankit
#   Downloading trankit-1.1.2-py3-none-any.whl.metadata (13 kB)
# Collecting adapters>=0.1.1 (from trankit)
#   Downloading adapters-1.1.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from trankit) (4.50.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from trankit) (1.26.4)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from trankit) (5.29.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from trankit) (2.32.3)
# Requirement already satisfied: torch<=2.0.1,>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from trankit) (2.0.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from trankit) (4.67.1)
# Collecting langid==1.1.6 (from trankit)
#   Downloading langid-1.1.6.tar.gz (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 30.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from trankit) (3.18.0)
# Requirement already satisfied: tokenizers>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from trankit) (0.21.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from trankit) (2024.11.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from trankit) (24.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from trankit) (0.2.0)
# Collecting sacremoses (from trankit)
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from trankit) (1.17.0)
# Collecting transformers (from trankit)
#   Downloading transformers-4.47.1-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers>=0.7.0->trankit) (0.30.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (4.13.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.11/dist-packages (from torch<=2.0.1,>=1.6.0->trankit) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<=2.0.1,>=1.6.0->trankit) (75.2.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<=2.0.1,>=1.6.0->trankit) (0.45.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch<=2.0.1,>=1.6.0->trankit) (3.31.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch<=2.0.1,>=1.6.0->trankit) (18.1.8)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers->trankit) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from transformers->trankit) (0.5.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->trankit) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->trankit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->trankit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->trankit) (2025.1.31)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from sacremoses->trankit) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from sacremoses->trankit) (1.4.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.7.0->trankit) (2025.3.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<=2.0.1,>=1.6.0->trankit) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch<=2.0.1,>=1.6.0->trankit) (1.3.0)
# Downloading trankit-1.1.2-py3-none-any.whl (92 kB)
# Downloading adapters-1.1.0-py3-none-any.whl (293 kB)
# Downloading transformers-4.47.1-py3-none-any.whl (10.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 116.5 MB/s eta 0:00:00
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 37.9 MB/s eta 0:00:00
# Building wheels for collected packages: langid
#   Building wheel for langid (setup.py) ... done
#   Created wheel for langid: filename=langid-1.1.6-py3-none-any.whl size=1941171 sha256=485efd4ffd8c94c239e2296d1953265fa0e9d47a0f74fcd5b549c9900240ad7d
#   Stored in directory: /root/.cache/pip/wheels/32/6a/b6/b7eb43a6ad55b139c15c5daa29f3707659cfa6944d3c696f5b
# Successfully built langid
# Installing collected packages: sacremoses, langid, transformers, adapters, trankit
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.50.3
#     Uninstalling transformers-4.50.3:
#       Successfully uninstalled transformers-4.50.3
# Successfully installed adapters-1.1.0 langid-1.1.6 sacremoses-0.1.1 trankit-1.1.2 transformers-4.47.1

# %% [markdown]
# ---
#
#
# **Restart kernel here(?)**
#
#
# ---

# %%
import trankit
from trankit import Pipeline, trankit2conllu
# If you get an error about numpy not found, restart the kernel.

# %%
# !pwd
# %cd trankit/MM_proiel/
# !pwd
# Out:
# /content
# /content/trankit/MM_proiel
# /content/trankit/MM_proiel

# %%
trankit.verify_customized_pipeline(
    category='customized-mwt', # pipeline category
    save_dir='./save_dir', # directory used for saving models in previous steps
    embedding_name='xlm-roberta-base' # embedding version that we use for training our customized pipeline, by default, it is `xlm-roberta-base`
)
# Out:
# Customized pipeline is ready to use!
# It can be initialized as follows:
# -----------------------------------
# from trankit import Pipeline
# p = Pipeline(lang='customized-mwt', cache_dir='./save_dir')

# %%
p = Pipeline(lang='customized-mwt', cache_dir='./save_dir')
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# Loading pretrained XLM-Roberta, this may take a while...
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# Loading tokenizer for customized-mwt
# Loading tagger for customized-mwt
# Loading multi-word expander for customized-mwt
# Loading lemmatizer for customized-mwt
# ==================================================
# Active language: customized-mwt
# ==================================================
# /usr/local/lib/python3.11/dist-packages/adapters/composition.py:225: FutureWarning: Passing list objects for adapter activation is deprecated. Please use Stack or Fuse explicitly.
#   warnings.warn(

# %%
doc = '''In Catilinam orationes Cicero consul contra Catilinam et coniurationem eius declamavit.

Prima oratio, in senatu, brevis est, sed discipuli latinae linguae saepe eam legunt quod facilior lectu est quam alia carmina et orationes. '''

# perform all tasks on the input
processed_doc = p(doc)

# %%
from pprint import pprint

pprint(processed_doc)
# Out:
# {'lang': 'customized-mwt',
#  'sentences': [{'dspan': (0, 87),
#                 'id': 1,
#                 'text': 'In Catilinam orationes Cicero consul contra Catilinam '
#                         'et coniurationem eius declamavit.',
#                 'tokens': [{'deprel': 'case',
#                             'dspan': (0, 2),
#                             'head': 2,
#                             'id': 1,
#                             'lemma': 'in',
#                             'span': (0, 2),
#                             'text': 'In',
#                             'upos': 'ADP',
#                             'xpos': 'r--------'},
#                            {'deprel': 'obl',
#                             'dspan': (3, 12),
#                             'feats': 'Case=Acc|Gender=Fem|Number=Sing',
#                             'head': 11,
#                             'id': 2,
#                             'lemma': 'Catilina',
#                             'span': (3, 12),
#                             'text': 'Catilinam',
#                             'upos': 'PROPN',
#                             'xpos': 'n-s---fa-'},
#                            {'deprel': 'obj',
#                             'dspan': (13, 22),
#                             'feats': 'Case=Acc|Gender=Fem|Number=Plur',
#                             'head': 11,
#                             'id': 3,
#                             'lemma': 'oratio',
#                             'span': (13, 22),
#                             'text': 'orationes',
#                             'upos': 'NOUN',
#                             'xpos': 'n-p---fa-'},
#                            {'deprel': 'nsubj',
#                             'dspan': (23, 29),
#                             'feats': 'Case=Nom|Gender=Masc|Number=Sing',
#                             'head': 11,
#                             'id': 4,
#                             'lemma': 'Cicero',
#                             'span': (23, 29),
#                             'text': 'Cicero',
#                             'upos': 'PROPN',
#                             'xpos': 'n-s---mn-'},
#                            {'deprel': 'xcomp',
#                             'dspan': (30, 36),
#                             'feats': 'Case=Nom|Gender=Masc|Number=Sing',
#                             'head': 4,
#                             'id': 5,
#                             'lemma': 'consul',
#                             'span': (30, 36),
#                             'text': 'consul',
#                             'upos': 'NOUN',
#                             'xpos': 'n-s---mn-'},
#                            {'deprel': 'case',
#                             'dspan': (37, 43),
#                             'head': 7,
#                             'id': 6,
#                             'lemma': 'contra',
#                             'span': (37, 43),
#                             'text': 'contra',
#                             'upos': 'ADP',
#                             'xpos': 'r--------'},
#                            {'deprel': 'obl',
#                             'dspan': (44, 53),
#                             'feats': 'Case=Acc|Gender=Masc|Number=Sing',
#                             'head': 11,
#                             'id': 7,
#                             'lemma': 'Catilina',
#                             'span': (44, 53),
#                             'text': 'Catilinam',
#                             'upos': 'PROPN',
#                             'xpos': 'n-s---ma-'},
#                            {'deprel': 'cc',
#                             'dspan': (54, 56),
#                             'head': 9,
#                             'id': 8,
#                             'lemma': 'et',
#                             'span': (54, 56),
#                             'text': 'et',
#                             'upos': 'CCONJ',
#                             'xpos': 'c--------'},
#                            {'deprel': 'conj',
#                             'dspan': (57, 70),
#                             'feats': 'Case=Acc|Gender=Fem|Number=Sing',
#                             'head': 7,
#                             'id': 9,
#                             'lemma': 'coniuratio',
#                             'span': (57, 70),
#                             'text': 'coniurationem',
#                             'upos': 'NOUN',
#                             'xpos': 'n-s---fa-'},
#                            {'deprel': 'nmod',
#                             'dspan': (71, 75),
#                             'feats': 'Case=Gen|Gender=Masc|Number=Sing|Person=3|PronType=Prs',
#                             'head': 9,
#                             'id': 10,
#                             'lemma': 'is',
#                             'span': (71, 75),
#                             'text': 'eius',
#                             'upos': 'PRON',
#                             'xpos': 'p-s---mg-'},
#                            {'deprel': 'root',
#                             'dspan': (76, 86),
#                             'feats': 'Aspect=Perf|Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin|Voice=Act',
#                             'head': 0,
#                             'id': 11,
#                             'lemma': 'declamavit',
#                             'span': (76, 86),
#                             'text': 'declamavit',
#                             'upos': 'VERB',
#                             'xpos': 'v3sria---'},
#                            {'deprel': 'punct',
#                             'dspan': (86, 87),
#                             'head': 11,
#                             'id': 12,
#                             'lemma': '.',
#                             'span': (86, 87),
#                             'text': '.',
#                             'upos': 'PUNCT',
#                             'xpos': 'u--------'}]},
#                {'dspan': (89, 228),
#                 'id': 2,
#                 'text': 'Prima oratio, in senatu, brevis est, sed discipuli '
#                         'latinae linguae saepe eam legunt quod facilior lectu '
#                         'est quam alia carmina et orationes.',
#                 'tokens': [{'deprel': 'amod',
#                             'dspan': (89, 94),
#                             'feats': 'Case=Abl|Gender=Fem|Number=Sing|NumType=Ord',
#                             'head': 2,
#                             'id': 1,
#                             'lemma': 'Prima',
#                             'span': (0, 5),
#                             'text': 'Prima',
#                             'upos': 'ADJ',
#                             'xpos': 'm-s---fn-'},
#                            {'deprel': 'nsubj',
#                             'dspan': (95, 101),
#                             'feats': 'Case=Nom|Gender=Fem|Number=Sing',
#                             'head': 7,
#                             'id': 2,
#                             'lemma': 'oratio',
#                             'span': (6, 12),
#                             'text': 'oratio',
#                             'upos': 'NOUN',
#                             'xpos': 'n-s---fn-'},
#                            {'deprel': 'punct',
#                             'dspan': (101, 102),
#                             'head': 5,
#                             'id': 3,
#                             'lemma': ',',
#                             'span': (12, 13),
#                             'text': ',',
#                             'upos': 'PUNCT',
#                             'xpos': 'u--------'},
#                            {'deprel': 'case',
#                             'dspan': (103, 105),
#                             'head': 5,
#                             'id': 4,
#                             'lemma': 'in',
#                             'span': (14, 16),
#                             'text': 'in',
#                             'upos': 'ADP',
#                             'xpos': 'r--------'},
#                            {'deprel': 'obl',
#                             'dspan': (106, 112),
#                             'feats': 'Case=Abl|Gender=Masc|Number=Sing',
#                             'head': 7,
#                             'id': 5,
#                             'lemma': 'senatus',
#                             'span': (17, 23),
#                             'text': 'senatu',
#                             'upos': 'NOUN',
#                             'xpos': 'n-s---mb-'},
#                            {'deprel': 'punct',
#                             'dspan': (112, 113),
#                             'head': 2,
#                             'id': 6,
#                             'lemma': ',',
#                             'span': (23, 24),
#                             'text': ',',
#                             'upos': 'PUNCT',
#                             'xpos': 'u--------'},
#                            {'deprel': 'root',
#                             'dspan': (114, 120),
#                             'feats': 'Case=Nom|Gender=Fem|Number=Sing',
#                             'head': 0,
#                             'id': 7,
#                             'lemma': 'brevis',
#                             'span': (25, 31),
#                             'text': 'brevis',
#                             'upos': 'ADJ',
#                             'xpos': 'a-s---fn-'},
#                            {'deprel': 'cop',
#                             'dspan': (121, 124),
#                             'feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#                             'head': 7,
#                             'id': 8,
#                             'lemma': 'sum',
#                             'span': (32, 35),
#                             'text': 'est',
#                             'upos': 'AUX',
#                             'xpos': 'v3spia---'},
#                            {'deprel': 'punct',
#                             'dspan': (124, 125),
#                             'head': 16,
#                             'id': 9,
#                             'lemma': ',',
#                             'span': (35, 36),
#                             'text': ',',
#                             'upos': 'PUNCT',
#                             'xpos': 'u--------'},
#                            {'deprel': 'cc',
#                             'dspan': (126, 129),
#                             'head': 16,
#                             'id': 10,
#                             'lemma': 'sed',
#                             'span': (37, 40),
#                             'text': 'sed',
#                             'upos': 'CCONJ',
#                             'xpos': 'c--------'},
#                            {'deprel': 'nsubj',
#                             'dspan': (130, 139),
#                             'feats': 'Case=Nom|Gender=Masc|Number=Plur',
#                             'head': 16,
#                             'id': 11,
#                             'lemma': 'discipuli',
#                             'span': (41, 50),
#                             'text': 'discipuli',
#                             'upos': 'NOUN',
#                             'xpos': 'n-p---mn-'},
#                            {'deprel': 'amod',
#                             'dspan': (140, 147),
#                             'feats': 'Case=Gen|Gender=Fem|Number=Sing',
#                             'head': 13,
#                             'id': 12,
#                             'lemma': 'latinae',
#                             'span': (51, 58),
#                             'text': 'latinae',
#                             'upos': 'ADJ',
#                             'xpos': 'a-s---fg-'},
#                            {'deprel': 'nmod',
#                             'dspan': (148, 155),
#                             'feats': 'Case=Gen|Gender=Fem|Number=Sing',
#                             'head': 11,
#                             'id': 13,
#                             'lemma': 'lingua',
#                             'span': (59, 66),
#                             'text': 'linguae',
#                             'upos': 'NOUN',
#                             'xpos': 'n-s---fg-'},
#                            {'deprel': 'advmod:tmod',
#                             'dspan': (156, 161),
#                             'feats': 'AdvType=Tim',
#                             'head': 16,
#                             'id': 14,
#                             'lemma': 'saepe',
#                             'span': (67, 72),
#                             'text': 'saepe',
#                             'upos': 'ADV',
#                             'xpos': 'd--------'},
#                            {'deprel': 'obj',
#                             'dspan': (162, 165),
#                             'feats': 'Case=Acc|Gender=Fem|Number=Sing|Person=3|PronType=Prs',
#                             'head': 16,
#                             'id': 15,
#                             'lemma': 'is',
#                             'span': (73, 76),
#                             'text': 'eam',
#                             'upos': 'PRON',
#                             'xpos': 'p-s---fa-'},
#                            {'deprel': 'conj',
#                             'dspan': (166, 172),
#                             'feats': 'Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act',
#                             'head': 7,
#                             'id': 16,
#                             'lemma': 'legunt',
#                             'span': (77, 83),
#                             'text': 'legunt',
#                             'upos': 'VERB',
#                             'xpos': 'v3ppia---'},
#                            {'deprel': 'mark',
#                             'dspan': (173, 177),
#                             'head': 18,
#                             'id': 17,
#                             'lemma': 'quod',
#                             'span': (84, 88),
#                             'text': 'quod',
#                             'upos': 'SCONJ',
#                             'xpos': 'c--------'},
#                            {'deprel': 'advcl',
#                             'dspan': (178, 186),
#                             'feats': 'Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing',
#                             'head': 16,
#                             'id': 18,
#                             'lemma': 'facilis',
#                             'span': (89, 97),
#                             'text': 'facilior',
#                             'upos': 'ADJ',
#                             'xpos': 'a-s---mnc'},
#                            {'deprel': 'obl',
#                             'dspan': (187, 192),
#                             'feats': 'Case=Abl|Gender=Masc|Number=Sing',
#                             'head': 18,
#                             'id': 19,
#                             'lemma': 'lectu',
#                             'span': (98, 103),
#                             'text': 'lectu',
#                             'upos': 'NOUN',
#                             'xpos': 'n-s---mb-'},
#                            {'deprel': 'cop',
#                             'dspan': (193, 196),
#                             'feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin',
#                             'head': 18,
#                             'id': 20,
#                             'lemma': 'sum',
#                             'span': (104, 107),
#                             'text': 'est',
#                             'upos': 'AUX',
#                             'xpos': 'v3spia---'},
#                            {'deprel': 'mark',
#                             'dspan': (197, 201),
#                             'head': 23,
#                             'id': 21,
#                             'lemma': 'quam',
#                             'span': (108, 112),
#                             'text': 'quam',
#                             'upos': 'SCONJ',
#                             'xpos': 'd--------'},
#                            {'deprel': 'det',
#                             'dspan': (202, 206),
#                             'feats': 'Case=Acc|Gender=Neut|Number=Plur|PronType=Con',
#                             'head': 23,
#                             'id': 22,
#                             'lemma': 'alius',
#                             'span': (113, 117),
#                             'text': 'alia',
#                             'upos': 'DET',
#                             'xpos': 'a-p---na-'},
#                            {'deprel': 'nsubj',
#                             'dspan': (207, 214),
#                             'feats': 'Case=Acc|Gender=Neut|Number=Plur',
#                             'head': 18,
#                             'id': 23,
#                             'lemma': 'carmen',
#                             'span': (118, 125),
#                             'text': 'carmina',
#                             'upos': 'NOUN',
#                             'xpos': 'n-p---na-'},
#                            {'deprel': 'cc',
#                             'dspan': (215, 217),
#                             'head': 25,
#                             'id': 24,
#                             'lemma': 'et',
#                             'span': (126, 128),
#                             'text': 'et',
#                             'upos': 'CCONJ',
#                             'xpos': 'c--------'},
#                            {'deprel': 'conj',
#                             'dspan': (218, 227),
#                             'feats': 'Case=Acc|Gender=Fem|Number=Plur',
#                             'head': 23,
#                             'id': 25,
#                             'lemma': 'oratio',
#                             'span': (129, 138),
#                             'text': 'orationes',
#                             'upos': 'NOUN',
#                             'xpos': 'n-p---fa-'},
#                            {'deprel': 'punct',
#                             'dspan': (227, 228),
#                             'head': 7,
#                             'id': 26,
#                             'lemma': '.',
#                             'span': (138, 139),
#                             'text': '.',
#                             'upos': 'PUNCT',
#                             'xpos': 'u--------'}]}],
#  'text': 'In Catilinam orationes Cicero consul contra Catilinam et '
#          'coniurationem eius declamavit.\n'
#          '\n'
#          'Prima oratio, in senatu, brevis est, sed discipuli latinae linguae '
#          'saepe eam legunt quod facilior lectu est quam alia carmina et '
#          'orationes. '}

# %%
conlludoc = trankit2conllu(processed_doc)
print(conlludoc)
# Out:
# 1	In	in	ADP	R-	AdpType=Prep	2	case	_	_
# 2	Catilinam	Catilina	PROPN	Ne	Case=Acc|Gender=Fem|Number=Sing	11	obl	_	_
# 3	orationes	oratio	NOUN	Nb	Case=Acc|Gender=Fem|Number=Plur	11	obj	_	_
# 4	Cicero	Cicero	PROPN	Ne	Case=Nom|Gender=Masc|Number=Sing	11	nsubj	_	_
# 5	consul	consul	NOUN	Nb	Case=Nom|Gender=Masc|Number=Sing	4	appos	_	_
# 6	contra	contra	ADP	R-	AdpType=Prep	7	case	_	_
# 7	Catilinam	Catilina	PROPN	Ne	Case=Acc|Gender=Masc|Number=Sing	5	nmod	_	_
# 8	et	et	CCONJ	C-	_	9	cc	_	_
# 9	coniurationem	coniuratio	NOUN	Nb	Case=Acc|Gender=Fem|Number=Sing	3	conj	_	_
# 10	eius	is	PRON	Pp	Case=Gen|Gender=Masc|Number=Sing|Person=3|PronType=Prs	9	nmod	_	_
# 11	declamavit	declamavit	VERB	V-	Aspect=Perf|Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin|Voice=Act	0	root	_	_
# 12	.	.	PUNCT	_	_	9	cc	_	_
#
# 1	Prima	primus	ADJ	Mo	Case=Nom|Gender=Fem|Number=Sing|NumType=Ord	2	amod	_	_
# 2	oratio	oratio	NOUN	Nb	Case=Nom|Gender=Fem|Number=Sing	7	nsubj	_	_
# 3	,	,	PART	Df	_	5	case	_	_
# 4	in	in	ADP	R-	AdpType=Prep	5	case	_	_
# 5	senatu	senatus	NOUN	Nb	Case=Abl|Gender=Masc|Number=Sing	7	obl	_	_
# 6	,	,	PART	Df	_	5	case	_	_
# 7	brevis	brevis	ADJ	A-	Case=Nom|Gender=Fem|Number=Sing	0	root	_	_
# 8	est	sum	AUX	V-	Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	7	cop	_	_
# 9	,	,	CCONJ	C-	_	16	cc	_	_
# 10	sed	sed	CCONJ	C-	_	16	cc	_	_
# 11	discipuli	discipulus	NOUN	Nb	Case=Nom|Gender=Masc|Number=Plur	16	nsubj	_	_
# 12	latinae	latinae	ADJ	A-	Case=Gen|Gender=Fem|Number=Sing	13	amod	_	_
# 13	linguae	lingua	NOUN	Nb	Case=Gen|Gender=Fem|Number=Sing	11	nmod	_	_
# 14	saepe	saepe	ADV	Df	AdvType=Tim	16	advmod:tmod	_	_
# 15	eam	is	PRON	Pp	Case=Acc|Gender=Fem|Number=Sing|Person=3|PronType=Prs	16	obj	_	_
# 16	legunt	legunt	VERB	V-	Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin|Voice=Act	7	conj	_	_
# 17	quod	quod	SCONJ	G-	PronType=Rel	18	mark	_	_
# 18	facilior	facilis	ADJ	A-	Case=Nom|Degree=Cmp|Gender=Masc|Number=Sing	16	advcl	_	_
# 19	lectu	lectu	ADV	Df	Case=Abl|Gender=Masc|Number=Sing	18	obl	_	_
# 20	est	sum	AUX	V-	Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	18	cop	_	_
# 21	quam	quam	SCONJ	Df	PronType=Rel	23	mark	_	_
# 22	alia	alius	DET	Px	Case=Nom|Gender=Neut|Number=Plur|PronType=Con	23	det	_	_
# 23	carmina	carmina	NOUN	Nb	Case=Nom|Gender=Neut|Number=Plur	18	advcl:cmp	_	_
# 24	et	et	CCONJ	C-	_	25	cc	_	_
# 25	orationes	oratio	NOUN	Nb	Case=Nom|Gender=Fem|Number=Plur	23	conj	_	_
# 26	.	.	PUNCT	_	_	18	punct	_	_

# %%
# # [Ctrl + /] to Comment/Uncomment lines.
# # Select all in the cell (Ctrl-A) to handle the whole cell.

# # Maybe exclude these instead of deleting?
# # Or only include the five files?
# # !rm -r save_dir/xlm-roberta-base/models--xlm-roberta-base/
# # !rm save_dir/xlm-roberta-base/customized-mwt/customized-mwt.downloaded

# %cd /content/

# # Zip it excluding hidden files:
# !zip -r MM_proiel MM_proiel/ -x "*/.*"

# # Zip the five files only:
# %cd /content/
# !zip -r trankit-MM_proiel trankit/MM_proiel/save_dir/xlm-roberta-base/customized-mwt/ -x "*.downloaded"
# Out:
# /content
#   adding: trankit/MM_proiel/save_dir/xlm-roberta-base/customized-mwt/ (stored 0%)
#   adding: trankit/MM_proiel/save_dir/xlm-roberta-base/customized-mwt/customized-mwt_mwt_expander.pt (deflated 9%)
#   adding: trankit/MM_proiel/save_dir/xlm-roberta-base/customized-mwt/customized-mwt.tokenizer.mdl (deflated 7%)
#   adding: trankit/MM_proiel/save_dir/xlm-roberta-base/customized-mwt/customized-mwt.vocabs.json (deflated 89%)
#   adding: trankit/MM_proiel/save_dir/xlm-roberta-base/customized-mwt/customized-mwt.tagger.mdl (deflated 8%)
#   adding: trankit/MM_proiel/save_dir/xlm-roberta-base/customized-mwt/customized-mwt_lemmatizer.pt (deflated 35%)
