# %%
# !rm -r sample_data/

# %%
# !wget -nc https://a3s.fi/Latin-parsers-public/stanza-MM_llct.zip
# !unzip -n stanza-MM_llct.zip
# !unzip -n stanza-all.zip
# Out:
# Archive:  stanza-all.zip
#    creating: stanza/
#    creating: stanza/MERG_Classical/
#    creating: stanza/MERG_Classical/saved_models/
#    creating: stanza/MERG_Classical/saved_models/depparse/
#   inflating: stanza/MERG_Classical/saved_models/depparse/la_perseusproiel_nocharlm_parser.pt
#    creating: stanza/MERG_Classical/saved_models/lemma/
#   inflating: stanza/MERG_Classical/saved_models/lemma/la_perseusproiel_nocharlm_lemmatizer.pt
#    creating: stanza/MERG_Classical/saved_models/mwt/
#   inflating: stanza/MERG_Classical/saved_models/mwt/la_perseusproiel_mwt_expander.pt
#    creating: stanza/MERG_Classical/saved_models/pos/
#   inflating: stanza/MERG_Classical/saved_models/pos/la_perseusproiel_nocharlm_tagger.pt
#    creating: stanza/MERG_Classical/saved_models/tokenize/
#   inflating: stanza/MERG_Classical/saved_models/tokenize/la_perseusproiel_tokenizer.pt
#    creating: stanza/MERG_Five-Merged/
#    creating: stanza/MERG_Five-Merged/saved_models/
# ...

# %%
# !ls -lhR
# Out:
# .:
# total 116M
# drwxrwxrwx 3 root root 4.0K Apr  5 20:20 stanza
# -rw-r--r-- 1 root root 116M Apr  5 20:32 stanza-MM_ittb.zip
#
# ./stanza:
# total 4.0K
# drwxrwxrwx 3 root root 4.0K Apr  5 20:17 MM_ittb
#
# ./stanza/MM_ittb:
# total 4.0K
# drwxrwxrwx 7 root root 4.0K Apr  5 20:16 saved_models
#
# ./stanza/MM_ittb/saved_models:
# total 20K
# drwxrwxrwx 2 root root 4.0K Apr  5 20:16 depparse
# drwxrwxrwx 2 root root 4.0K Apr  5 20:16 lemma
# drwxrwxrwx 2 root root 4.0K Apr  5 20:16 mwt
# drwxrwxrwx 2 root root 4.0K Apr  5 20:16 pos
# drwxrwxrwx 2 root root 4.0K Apr  5 20:16 tokenize
#
# ./stanza/MM_ittb/saved_models/depparse:
# total 101M
# -rw-rw-rw- 1 root root 101M Feb 19  2024 la_ittb_nocharlm_parser.pt
#
# ./stanza/MM_ittb/saved_models/lemma:
# total 3.1M
# -rw-rw-rw- 1 root root 3.1M Feb 18  2024 la_ittb_nocharlm_lemmatizer.pt
#
# ./stanza/MM_ittb/saved_models/mwt:
# total 532K
# -rw-rw-rw- 1 root root 529K Feb 18  2024 la_ittb_mwt_expander.pt
#
# ...

# %%
# %pip install --upgrade pip
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 18.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...

# %%
# %pip install stanza
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 48.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 142.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 58.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 25.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 66.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 58.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 61.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 68.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 146.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 590.6/590.6 kB 25.5 MB/s eta 0:00:00
# ...

# %%
import stanza

# %%
# !pwd
# %cd /content/stanza/
# !pwd
# Out:
# /content
# /content/stanza
# /content/stanza

# %%
dir = "MM_llct"
model = "llct"

config = {
        'processors': 'tokenize,mwt,lemma,pos,depparse',
        'lang': 'la',
        'tokenize_model_path': f'./{dir}/saved_models/tokenize/la_{model}_tokenizer.pt',
        'mwt_model_path': f'./{dir}/saved_models/mwt/la_{model}_mwt_expander.pt',
        'lemma_model_path': f'./{dir}/saved_models/lemma/la_{model}_nocharlm_lemmatizer.pt',
        'pos_model_path': f'./{dir}/saved_models/pos/la_{model}_nocharlm_tagger.pt',
        'depparse_model_path': f'./{dir}/saved_models/depparse/la_{model}_nocharlm_parser.pt',
    }

nlp = stanza.Pipeline(**config)

# Note: Downloads files to /root/stanza_resources/ in Colab,
# !whoami  # ---> root
# so user's home directory actually?
# Out:
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# ...
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# ...
# INFO:stanza:Loading these models for language: la (Latin):
# ...
# | Processor | Package                 |
# ---------------------------------------
# | tokenize  | ./MM_llct/...kenizer.pt |
# | mwt       | ./MM_llct/...xpander.pt |
# | pos       | ./MM_llct/..._tagger.pt |
# | lemma     | ./MM_llct/...matizer.pt |
# | depparse  | ./MM_llct/..._parser.pt |
# ...
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Done loading processors!

# %%
test_document = '''In Catilinam orationes Cicero consul contra Catilinam et coniurationem eius declamavit.

Prima oratio, in senatu, brevis est, sed discipuli latinae linguae saepe eam legunt quod facilior lectu est quam alia carmina et orationes. '''

doc = nlp(test_document)

# %%
from stanza.utils.conll import CoNLL

outfile = "output.conllu"

CoNLL.write_doc2conll(doc, outfile)

# %%
from pprint import pprint

pprint(doc)
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "In",
#       "lemma": "In",
#       "upos": "ADP",
#       "xpos": "S4",
#       "feats": "AdpType=Prep",
#       "head": 2,
#       "deprel": "case",
#       "start_char": 0,
#       "end_char": 2
#     },
#     {
#       "id": 2,
#       "text": "Catilinam",
#       "lemma": "Catilinus",
#       "upos": "ADJ",
#       "xpos": "A1|grn1|casD|gen2",
#       "feats": "Case=Acc|Gender=Fem|InflClass=IndEurA|Number=Sing",
#       "head": 11,
#       "deprel": "obl",
#       "start_char": 3,
#       "end_char": 12
#     },
#     {
#       "id": 3,
#       "text": "orationes",
#       "lemma": "oratio",
#       "upos": "NOUN",
#       "xpos": "C1|grn1|casM|gen2",
#       "feats": "Case=Acc|Gender=Fem|InflClass=IndEurX|Number=Plur",
#       "head": 11,
#       "deprel": "obj",
#       "start_char": 13,
#       "end_char": 22
#     },
#     {
#       "id": 4,
#       "text": "Cicero",
#       "lemma": "Cicer",
#       "upos": "NOUN",
# ...

# %%
# # [Ctrl + /] to Comment/Uncomment lines.

# %cd /content/

# # Zip it excluding hidden files:
# # !zip -r MM_llct MM_llct/ -x "*/.*"

# # Zip the five files only:
# %cd /content/
# !zip -r stanza-MM_llct stanza/MM_llct -x "output.conllu"
# WARNING: Commands not tested for stanza!
# Out:
# /content
#   adding: stanza/MM_llct/ (stored 0%)
#   adding: stanza/MM_llct/saved_models/ (stored 0%)
#   adding: stanza/MM_llct/saved_models/depparse/ (stored 0%)
#   adding: stanza/MM_llct/saved_models/depparse/la_llct_nocharlm_parser.pt (deflated 9%)
#   adding: stanza/MM_llct/saved_models/mwt/ (stored 0%)
#   adding: stanza/MM_llct/saved_models/mwt/la_llct_mwt_expander.pt (deflated 8%)
#   adding: stanza/MM_llct/saved_models/tokenize/ (stored 0%)
#   adding: stanza/MM_llct/saved_models/tokenize/la_llct_tokenizer.pt (deflated 8%)
#   adding: stanza/MM_llct/saved_models/pos/ (stored 0%)
#   adding: stanza/MM_llct/saved_models/pos/la_llct_nocharlm_tagger.pt (deflated 10%)
#   adding: stanza/MM_llct/saved_models/lemma/ (stored 0%)
#   adding: stanza/MM_llct/saved_models/lemma/la_llct_nocharlm_lemmatizer.pt (deflated 21%)
